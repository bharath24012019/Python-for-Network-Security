# %%
p = 23   
g = 5    
 
a = 6
b = 15

# %%
print( "Publicly Shared Variables:")
print( "    Publicly Shared p: " , p )
print( "    Publicly Shared g:  " , g )
# Out:
# Publicly Shared Variables:
#     Publicly Shared p:  23
#     Publicly Shared g:   5

# %%
# Alice Sends Bob A = g^a mod p
A = (g ** a) % p
print( "\nAlice Sends Over Public Chanel: " , A )
 
# Bob Sends Alice B = g^b mod p
B = (g ** b) % p
print("Bob Sends Over Public Chanel: ", B )
# Out:
# Alice Sends Over Public Chanel:  8
# Bob Sends Over Public Chanel:  19

# %%
print( "Privately Calculated Shared Secret:" )
# Alice Computes Shared Secret: s = B^a mod p
aliceSecret = (B ** a) % p
print( "    Alice Secret Key: ", aliceSecret )
 
# Bob Computes Shared Secret: s = A^b mod p
bobSecret = (A**b) % p
print( "    Bob Secret Key: ", bobSecret )
# Out:
# Privately Calculated Shared Secret:
#     Alice Secret Key:  2
#     Bob Secret Key:  2
